# %% [markdown]
# # Welcome to the Cluster!
#
# This Jupyter nootebook is a simple way to use the Project
#
# To learn more about the single components go to sub-directory 'examples'

# %% [markdown]
# For a random start run cell below

# %%
from conf import MainConf
import json
num = list()
num.append("1")
num.append("2")

str(num)


main_conf = MainConf.mainConfig()

# %%
 # %run ../../src/main
# Out:
# ../../src/main.py
# hello
# ...
